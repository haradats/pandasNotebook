# %% [markdown]
# <a href="https://colab.research.google.com/github/haradats/pandasNotebook/blob/main/pandasNote02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # DataFrameの作成

# %% [markdown]
# ## リストからDataFrameを作成する

# %%
lst = [[1,1,1], [2,4,8], [3,9,27]]
for x in lst:
  print(x)
# Out:
# [1, 1, 1]
# [2, 4, 8]
# [3, 9, 27]

# %%
df = pd.DataFrame(lst, columns=['linear','square','cubic'],index=['d1','d2','d3'])
df
# Out:
#     linear  square  cubic
# d1       1       1      1
# d2       2       4      8
# d3       3       9     27

# %%
df = pd.DataFrame(lst, columns=['linear','square','cubic'])
df
# Out:
#    linear  square  cubic
# 0       1       1      1
# 1       2       4      8
# 2       3       9     27

# %%
df = pd.DataFrame(lst)
df
# Out:
#    0  1   2
# 0  1  1   1
# 1  2  4   8
# 2  3  9  27

# %% [markdown]
# ## NumPyの配列からDataFrameを作成する

# %%
import numpy as np
ar = np.array(lst)
ar
# Out:
# array([[ 1,  1,  1],
#        [ 2,  4,  8],
#        [ 3,  9, 27]])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
df = pd.DataFrame(ar, columns=['linear', 'square', 'cubic'])
df
# Out:
#    linear  square  cubic
# 0       1       1      1
# 1       2       4      8
# 2       3       9     27

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 辞書からDataFrameを作成する

# %%
dc = {'linear':[1,2,3], 'square':[1,4,9], 'cubic':[1,8,27]}
dc
# Out:
# {'linear': [1, 2, 3], 'square': [1, 4, 9], 'cubic': [1, 8, 27]}

# %%
type(dc)
# Out:
# dict

# %%
print(dc)
# Out:
# {'linear': [1, 2, 3], 'square': [1, 4, 9], 'cubic': [1, 8, 27]}

# %%
df = pd.DataFrame(dc)
df
# Out:
#    linear  square  cubic
# 0       1       1      1
# 1       2       4      8
# 2       3       9     27

# %% [markdown]
# # DataFrameの要素へのアクセス

# %%
df2 = pd.DataFrame()    # 空のDataFrame
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## atによる要素へのアクセス

# %%
df2.at['d1','linear'] = 1
df2
# Out:
#     linear
# d1     1.0

# %%
df2.at['d2','square'] = 4
df2
# Out:
#     linear  square
# d1     1.0     NaN
# d2     NaN     4.0

# %%
df2.at['d3','cubic'] = 27
df2
# Out:
#     linear  square  cubic
# d1     1.0     NaN    NaN
# d2     NaN     4.0    NaN
# d3     NaN     NaN   27.0

# %%
### 実習: NaNの箇所にデータを埋める

# %%
df2.at['d1','square'] = 1
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    NaN
# d2     NaN     4.0    NaN
# d3     NaN     NaN   27.0

# %%
df2.at['d1', 'cubic']=1
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     NaN     4.0    NaN
# d3     NaN     NaN   27.0

# %%
df2.at['d2','linear'] = 2
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    NaN
# d3     NaN     NaN   27.0

# %%
df2.at['d2','cubic'] = 8
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     NaN     NaN   27.0

# %%
df2.at['d3','linear'] = 3
df2
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     NaN   27.0

# %%
df2.at['d3','square'] = 9
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0

# %% [markdown]
# ## NaNを一括して別の値に置き換える方法

# %%
df3 = pd.DataFrame()
df3.at['d1','linear'] = 1
df3.at['d2','square'] = 4
df3.at['d3','cubic' ] = 27
df3
# Out:
#     linear  square  cubic
# d1     1.0     NaN    NaN
# d2     NaN     4.0    NaN
# d3     NaN     NaN   27.0

# %%
df31 = df3.fillna(0)
df31
# Out:
#     linear  square  cubic
# d1     1.0     0.0    0.0
# d2     0.0     4.0    0.0
# d3     0.0     0.0   27.0

# %%
df3
# Out:
#     linear  square  cubic
# d1     1.0     NaN    NaN
# d2     NaN     4.0    NaN
# d3     NaN     NaN   27.0

# %% [markdown]
# ## iatによる要素へのアクセス

# %%
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0

# %%
df2.iat[2,1]
# Out:
# 9.0

# %% [markdown]
# ### iatは既存の領域にのみアクセス可能

# %%
# df2.iat[3,1]

# %% [markdown]
# ## locによるアクセス

# %%
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0

# %%
df2.loc['d1':'d2','linear':'square']
# Out:
#     linear  square
# d1     1.0     1.0
# d2     2.0     4.0

# %%
df2.loc['d1':'d2',:]
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0

# %%
df2.loc[:,'linear':'square']
# Out:
#     linear  square
# d1     1.0     1.0
# d2     2.0     4.0
# d3     3.0     9.0

# %%
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0

# %%
df2.loc[['d1','d3'],['linear','cubic']]
# Out:
#     linear  cubic
# d1     1.0    1.0
# d3     3.0   27.0

# %% [markdown]
# ## ilocによるアクセス

# %%
df2.iloc[0:2, 0:2]
# Out:
#     linear  square
# d1     1.0     1.0
# d2     2.0     4.0

# %%
df2.iloc[[0, 2], [0, 2]]
# Out:
#     linear  cubic
# d1     1.0    1.0
# d3     3.0   27.0

# %% [markdown]
# # 特定の列（カラム）にアクセスする方法

# %% [markdown]
# ## スライスを指定する方法

# %%
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0

# %%
df2[['linear','cubic']]
# Out:
#     linear  cubic
# d1     1.0    1.0
# d2     2.0    8.0
# d3     3.0   27.0

# %%
type(df2['linear'])
# Out:
# pandas.core.series.Series

# %%
c = pd.Series(['Taro', 'Jiro', 'Hanako'], index=['d1', 'd2', 'd3'])
c
# Out:
# d1      Taro
# d2      Jiro
# d3    Hanako
# dtype: object

# %%
df2['name'] = c

# %%
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako

# %% [markdown]
# ### 複数のカラムを取り出す方法

# %%
df2[['linear', 'cubic']]
# Out:
#     linear  cubic
# d1     1.0    1.0
# d2     2.0    8.0
# d3     3.0   27.0

# %% [markdown]
# ### 数値のカラム名も使用可能

# %%
df3 = pd.DataFrame([[1,2],[3,4]])
df3
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
df3[0]
# Out:
# 0    1
# 1    3
# Name: 0, dtype: int64

# %% [markdown]
# ## ドットを用いる方法

# %%
df4 = pd.DataFrame([['中村','大阪府',55],['田中','東京都',33]], columns=['name','address', 'age'])
df4
# Out:
#   name address  age
# 0   中村     大阪府   55
# 1   田中     東京都   33

# %%
df4.name
# Out:
# 0    中村
# 1    田中
# Name: name, dtype: object

# %% [markdown]
# ### 新規カラムの追加はできない！

# %%
df4.gender = ['男', '女']
# Out:
# <ipython-input-102-7ee78bd12629>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df4.gender = ['男', '女']

# %%
df4['gender'] = ['男', '女']
df4
# Out:
#   name address  age gender
# 0   中村     大阪府   55      男
# 1   田中     東京都   33      女

# %% [markdown]
# # 行の取り出し

# %%
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako

# %%
df2.loc['d2']
# Out:
# linear     2.0
# square     4.0
# cubic      8.0
# name      Jiro
# Name: d2, dtype: object

# %%
df2.iloc[1]
# Out:
# linear     2.0
# square     4.0
# cubic      8.0
# name      Jiro
# Name: d2, dtype: object

# %% [markdown]
# ### 結論）Seriesの形で得られ、元のDataFrameのカラムがインデックスとなる。

# %% [markdown]
# # 行の追加

# %%
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako

# %%
lin = pd.Series([4, 16, 64, 'Junko'], index=['linear', 'square', 'cubic', 'name'])
lin
# Out:
# linear        4
# square       16
# cubic        64
# name      Junko
# dtype: object

# %%
type(lin)
# Out:
# pandas.core.series.Series

# %%
df2.loc['d4'] = lin
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako
# d4     4.0    16.0   64.0   Junko

# %% [markdown]
# # DataFrameの内容をNumPyの配列に変換する方法

# %%
df2.values # 旧pandasでの方法
# Out:
# array([[1.0, 1.0, 1.0, 'Taro'],
#        [2.0, 4.0, 8.0, 'Jiro'],
#        [3.0, 9.0, 27.0, 'Hanako'],
#        [4.0, 16.0, 64.0, 'Junko']], dtype=object)

# %%
df2.to_numpy() # 新しいpandasでの方法（推奨）
# Out:
# array([[1.0, 1.0, 1.0, 'Taro'],
#        [2.0, 4.0, 8.0, 'Jiro'],
#        [3.0, 9.0, 27.0, 'Hanako'],
#        [4.0, 16.0, 64.0, 'Junko']], dtype=object)

# %% [markdown]
# # インデックス、カラムを明に取り出す方法

# %%
df2.index
# Out:
# Index(['d1', 'd2', 'd3', 'd4'], dtype='object')

# %%
df2.columns
# Out:
# Index(['linear', 'square', 'cubic', 'name'], dtype='object')

# %%
df2.index.to_numpy()
# Out:
# array(['d1', 'd2', 'd3', 'd4'], dtype=object)

# %%
type(df2.index)
# Out:
# pandas.core.indexes.base.Index

# %%
df2.columns.to_numpy()
# Out:
# array(['linear', 'square', 'cubic', 'name'], dtype=object)

# %% [markdown]
# ## 指定したインデックス、カラムの位置を調べる方法

# %%
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako
# d4     4.0    16.0   64.0   Junko

# %%
df2.index.get_loc('d3')
# Out:
# 2

# %%
df2.columns.get_loc('square')
# Out:
# 1

# %% [markdown]
# # 整列（ソート）

# %% [markdown]
# ## 値に沿った整列

# %%
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako
# d4     4.0    16.0   64.0   Junko

# %%
df21 = df2.sort_values(by='name')

# %%
df21
# Out:
#     linear  square  cubic    name
# d3     3.0     9.0   27.0  Hanako
# d2     2.0     4.0    8.0    Jiro
# d4     4.0    16.0   64.0   Junko
# d1     1.0     1.0    1.0    Taro

# %%
df22 = df2.sort_values(by='name', ascending=False)
df22
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d4     4.0    16.0   64.0   Junko
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako

# %%
df21
# Out:
#     linear  square  cubic    name
# d3     3.0     9.0   27.0  Hanako
# d2     2.0     4.0    8.0    Jiro
# d4     4.0    16.0   64.0   Junko
# d1     1.0     1.0    1.0    Taro

# %%
df21.sort_index()
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako
# d4     4.0    16.0   64.0   Junko

# %% [markdown]
# # 行、列の削除

# %%
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako
# d4     4.0    16.0   64.0   Junko

# %%
df22 = df2.drop('d4')
df22
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako

# %%
df22 = df2.drop(columns='name')
df22
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0
# d4     4.0    16.0   64.0

# %%
df2
# Out:
#     linear  square  cubic    name
# d1     1.0     1.0    1.0    Taro
# d2     2.0     4.0    8.0    Jiro
# d3     3.0     9.0   27.0  Hanako
# d4     4.0    16.0   64.0   Junko

# %%
df2.drop(index='d4', columns='cubic')
# Out:
#     linear  square    name
# d1     1.0     1.0    Taro
# d2     2.0     4.0    Jiro
# d3     3.0     9.0  Hanako

# %%
df22 = df2.drop(index=['d1','d4'], columns=['linear','cubic'])
df22
# Out:
#     square    name
# d2     4.0    Jiro
# d3     9.0  Hanako

# %% [markdown]
# ## カラムの抹消

# %%
del df2['name']

# %%
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0
# d4     4.0    16.0   64.0

# %% [markdown]
# # DataFrameの連結

# %% [markdown]
# ## 行方向に単純に連結する

# %%
dfA = pd.DataFrame([['1a', '1b'], ['2a', '2b']], index=['d1', 'd2'], columns=['a', 'b'])

# %%
dfA
# Out:
#      a   b
# d1  1a  1b
# d2  2a  2b

# %%
dfA = pd.DataFrame([['1a', '1b'], ['2a', '2b']], index=['d1', 'd2'], columns=['a', 'b'])
dfB = pd.DataFrame([['3a', '3b'], ['4a', '4b']], index=['d3', 'd4'], columns=['a', 'b'])

# %%
dfB
# Out:
#      a   b
# d3  3a  3b
# d4  4a  4b

# %%
display(dfA);display(dfB)
# Out:
#      a   b
# d1  1a  1b
# d2  2a  2b
#      a   b
# d3  3a  3b
# d4  4a  4b

# %%
dfAB = pd.concat([dfA, dfB])
dfAB
# Out:
#      a   b
# d1  1a  1b
# d2  2a  2b
# d3  3a  3b
# d4  4a  4b

# %%
dfBA = pd.concat([dfB, dfA])
dfBA
# Out:
#      a   b
# d3  3a  3b
# d4  4a  4b
# d1  1a  1b
# d2  2a  2b

# %% [markdown]
# ### 共通しないカラムがある場合

# %%
dfC = pd.DataFrame([['3c', '3d'], ['4c', '4d']], index=['d3', 'd4'], columns=['c', 'd'])
dfC
# Out:
#      c   d
# d3  3c  3d
# d4  4c  4d

# %%
dfAC = pd.concat([dfA, dfC])
dfAC
# Out:
#       a    b    c    d
# d1   1a   1b  NaN  NaN
# d2   2a   2b  NaN  NaN
# d3  NaN  NaN   3c   3d
# d4  NaN  NaN   4c   4d

# %% [markdown]
# ## 横方向（カラム方向）の連結

# %%
dfD = pd.DataFrame([['1e', '1f'], ['2e', '2f'], ['3e', '3f']], index=['d1', 'd2', 'd3'], columns=['e', 'f'])
dfD
# Out:
#      e   f
# d1  1e  1f
# d2  2e  2f
# d3  3e  3f

# %%
dfAD = pd.concat([dfA, dfD], axis=1)
dfAD
# Out:
#       a    b   e   f
# d1   1a   1b  1e  1f
# d2   2a   2b  2e  2f
# d3  NaN  NaN  3e  3f

# %%
dfA
# Out:
#      a   b
# d1  1a  1b
# d2  2a  2b

# %% [markdown]
# ### 結論）共通するインデックスが対応する

# %% [markdown]
# # 条件指定によるデータの抽出

# %%
df3 = pd.DataFrame([
    ['taro', 'male', 35],
    ['hanako', 'female', 31],
    ['jiro', 'male', 23],
    ['junko', 'female', 21]
], columns=['name', 'gender', 'age'])

# %%
df3
# Out:
#      name  gender  age
# 0    taro    male   35
# 1  hanako  female   31
# 2    jiro    male   23
# 3   junko  female   21

# %% [markdown]
# ## マスクの用意

# %%
cond = [False, True, False, False]
cond
# Out:
# [False, True, False, False]

# %% [markdown]
# ## スライスに真理値のマスクを与える

# %%
df31 = df3[cond]
df31
# Out:
#      name  gender  age
# 1  hanako  female   31

# %%
df3
# Out:
#      name  gender  age
# 0    taro    male   35
# 1  hanako  female   31
# 2    jiro    male   23
# 3   junko  female   21

# %%
df3[ df3['gender']=='female' ]
# Out:
#      name  gender  age
# 1  hanako  female   31
# 3   junko  female   21

# %%
df3['gender'] == 'female'
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: gender, dtype: bool

# %% [markdown]
# ## 複雑な条件式の使用

# %%
df3[(df3['gender']=='female') & (df3['age']<30)]   # 「かつ」で条件を連結
# Out:
#     name  gender  age
# 3  junko  female   21

# %%
df3[(df3['gender']=='male')]
# Out:
#    name gender  age
# 0  taro   male   35
# 2  jiro   male   23

# %%
df3[~(df3['gender']=='male')]   # 否定文
# Out:
#      name  gender  age
# 1  hanako  female   31
# 3   junko  female   21

# %% [markdown]
# # DataFrameに関する情報の取得

# %% [markdown]
# ## 要約統計量

# %%
df2
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0
# d4     4.0    16.0   64.0

# %%
df2.describe()
# Out:
#          linear     square      cubic
# count  4.000000   4.000000   4.000000
# mean   2.500000   7.500000  25.000000
# std    1.290994   6.557439  28.225284
# min    1.000000   1.000000   1.000000
# 25%    1.750000   3.250000   6.250000
# 50%    2.500000   6.500000  17.500000
# 75%    3.250000  10.750000  36.250000
# max    4.000000  16.000000  64.000000

# %% [markdown]
# ## データ構造に関する情報の取得

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, d1 to d4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   linear  4 non-null      float64
#  1   square  4 non-null      float64
#  2   cubic   4 non-null      float64
# dtypes: float64(3)
# memory usage: 300.0+ bytes

# %% [markdown]
# # 開始部分、終了部分の取り出し

# %%
df2.head()
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0
# d4     4.0    16.0   64.0

# %%
df2.tail()
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0
# d4     4.0    16.0   64.0

# %%
df2.head(2)
# Out:
#     linear  square  cubic
# d1     1.0     1.0    1.0
# d2     2.0     4.0    8.0

# %%
df2.tail(3)
# Out:
#     linear  square  cubic
# d2     2.0     4.0    8.0
# d3     3.0     9.0   27.0
# d4     4.0    16.0   64.0
